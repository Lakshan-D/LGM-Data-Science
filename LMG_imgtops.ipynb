# %% [markdown]
# <a href="https://colab.research.google.com/github/Lakshan-D/LGM-Data-Science/blob/main/LMG_imgtops.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Beginner Level Task 4**
# *Program To Convert Image To Pencil SKetch:*

# %% [markdown]
# **Programmer:** *Lakshan.D*

# %%
 from google.colab.patches import cv2_imshow
 import cv2

# %%
img=cv2.imread("/content/personal.jpg")
cv2_imshow(img)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=492x492 at 0x7F8DFD17C210>
# -1

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2_imshow( gray_image)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=L size=492x492 at 0x7F8DFE1D8210>
# -1

# %%
inverted_image = 255 - gray_image
cv2_imshow( inverted_image)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=L size=492x492 at 0x7F8DFD172290>
# -1

# %%
blurred = cv2.GaussianBlur(inverted_image, (21, 21), 0)
cv2_imshow(blurred)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=L size=492x492 at 0x7F8DFE1DD7D0>
# -1

# %%
inverted_blurred = 255 - blurred
pencil_sketch = cv2.divide(gray_image, inverted_blurred, scale=256.0)
cv2_imshow( pencil_sketch)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=L size=492x492 at 0x7F8DFD15FE90>
# -1

# %%
#Comparing start image & end result

cv2_imshow( image)
cv2_imshow( pencil_sketch)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=492x492 at 0x7F8DFE2832D0>
# <PIL.Image.Image image mode=L size=492x492 at 0x7F8DFD15F9D0>
# -1

# %% [markdown]
# #  Thank You
